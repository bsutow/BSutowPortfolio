# %%
#Setup#
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Prints data#
data= pd.read_csv('/Users/Brett/Downloads/dodgers.csv')
data
# Out:
#    month  day  attend day_of_week opponent  temp   skies day_night cap shirt  \
# 0    APR   10   56000     Tuesday  Pirates    67  Clear        Day  NO    NO
# 1    APR   11   29729   Wednesday  Pirates    58  Cloudy     Night  NO    NO
# 2    APR   12   28328    Thursday  Pirates    57  Cloudy     Night  NO    NO
# 3    APR   13   31601      Friday   Padres    54  Cloudy     Night  NO    NO
# 4    APR   14   46549    Saturday   Padres    57  Cloudy     Night  NO    NO
# ..   ...  ...     ...         ...      ...   ...     ...       ...  ..   ...
# 76   SEP   29   40724    Saturday  Rockies    84  Cloudy     Night  NO    NO
# 77   SEP   30   35607      Sunday  Rockies    95  Clear        Day  NO    NO
# 78   OCT    1   33624      Monday   Giants    86  Clear      Night  NO    NO
# 79   OCT    2   42473     Tuesday   Giants    83  Clear      Night  NO    NO
# 80   OCT    3   34014   Wednesday   Giants    82  Cloudy     Night  NO    NO
#
#    fireworks bobblehead
# ...

# %%
#Shows all unique and checks for errors#
print("Month:", data['month'].unique())
print("Days of Week:", data['day_of_week'].unique())
print("Opponent:", data['opponent'].unique())
print("Sky:", data['skies'].unique())
print("Day or Night:", data['day_night'].unique())
print("Cap Giveaway:", data['cap'].unique())
print("Shirt Giveaway:", data['shirt'].unique())
print("Fireworks:", data['fireworks'].unique())
print("Bobblehead Giveaway:", data['bobblehead'].unique())
# Out:
# Month: ['APR' 'MAY' 'JUN' 'JUL' 'AUG' 'SEP' 'OCT']
# Days of Week: ['Tuesday' 'Wednesday' 'Thursday' 'Friday' 'Saturday' 'Sunday' 'Monday']
# Opponent: ['Pirates' 'Padres' 'Braves' 'Nationals' 'Giants' 'Rockies' 'Snakes'
#  'Cardinals' 'Astros' 'Brewers' 'Angels' 'White Sox' 'Mets' 'Reds'
#  'Phillies' 'Cubs' 'Marlins']
# Sky: ['Clear ' 'Cloudy']
# Day or Night: ['Day' 'Night']
# Cap Giveaway: ['NO' 'YES']
# Shirt Giveaway: ['NO' 'YES']
# Fireworks: ['NO' 'YES']
# Bobblehead Giveaway: ['NO' 'YES']

# %%
#Plots a higogram to show the distribution
plt.rcParams['figure.figsize'] = [12, 10]
bins = [10000,15000,20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000,65000]
sns.distplot(data.attend, kde = False, bins = bins)
plt.xticks(bins)
plt.show()

# %%
#Looks at average temperature and game attendance#
x = {'temp':'temperature_average', 'attend':'attendance_average'}
tempdf = data.groupby('month').agg({'temp':'mean', 'attend':'mean'}).rename(columns=x).sort_values('temperature_average')
tempdf
# Out:
#        temperature_average  attendance_average
# month
# APR              63.000000        39591.916667
# MAY              68.555556        37345.722222
# JUN              70.555556        47940.444444
# JUL              73.166667        43884.250000
# AUG              77.333333        42751.533333
# OCT              83.666667        36703.666667
# SEP              84.250000        38955.083333

# %%
plt.scatter(x = 'temp', y = 'attend', data = data)
plt.show()

# %%
#Plots regression plot to look at attendance data further#
#Looks to see if there is a relationship between weather and game attendance#
sns.regplot(x = 'temp', y = 'attend', data = data)
plt.show()

# %%
#Box Plot showing attendance per month# 
#Shows a better breakdown of the average attendance per month compared to the max and mins#
sns.boxplot(x = 'month', y = 'attend', data = data)
plt.show()

# %%
#Shows same breakdown as above in easier to read fashion#
plt.scatter(x = 'month', y = 'attend', data = data)
plt.show()

# %%
#Bar shows attendance per month total#
plt.bar(x=data['month'], height=data['attend'], color='purple')
plt.xlabel('Month')
plt.ylabel('Attendance')
plt.show()

# %%
#Shows desciption of month data#
data.groupby('month').attend.describe()
# Out:
#        count          mean           std      min       25%      50%  \
# month
# APR     12.0  39591.916667  10882.001583  26345.0  29378.75  41186.5
# AUG     15.0  42751.533333   7256.695921  32659.0  37353.00  40284.0
# JUL     12.0  43884.250000   9399.324716  32238.0  34340.75  41914.0
# JUN      9.0  47940.444444   4919.203063  40432.0  44217.00  49006.0
# MAY     18.0  37345.722222   7721.822307  24312.0  33413.25  36422.0
# OCT      3.0  36703.666667   5000.193030  33624.0  33819.00  34014.0
# SEP     12.0  38955.083333   5135.247758  31607.0  35717.25  38650.0
#
#             75%      max
# month
# APR    47100.00  56000.0
# AUG    45062.50  56000.0
# JUL    53516.00  55359.0
# JUN    50559.00  55279.0
# MAY    43011.25  51137.0
# OCT    38243.50  42473.0
# SEP    41155.25  50560.0

# %%
#Box Plot showing attendance per month# 
#Shows a better breakdown of the average attendance per month compared to the max and mins#
sns.boxplot(x = 'day_of_week', y = 'attend', data = data)
plt.show()

# %%
#Shows same breakdown as above in easier to read fashion#
plt.scatter(x = 'day_of_week', y = 'attend', data = data, )
plt.show()

# %%
#Bar shows attendance per day of week total#
plt.bar(x=data['day_of_week'], height=data['attend'], color='purple')
plt.xlabel('Day of Week')
plt.ylabel('Attendance')
plt.show()

# %%
#Shows desciption of day of the week data#
data.groupby('day_of_week').attend.describe()
# Out:
#              count          mean           std      min       25%      50%  \
# day_of_week
# Friday        13.0  40116.923077   4694.879400  31601.0  37133.00  40167.0
# Monday        12.0  34965.666667   7005.957949  24312.0  32553.75  33582.0
# Saturday      13.0  43072.923077   6336.482298  33735.0  39383.00  42449.0
# Sunday        13.0  42268.846154   7596.350657  31607.0  35754.00  41907.0
# Thursday       5.0  40407.400000  12411.591328  26773.0  28328.00  43309.0
# Tuesday       13.0  47741.230769   8291.390044  32799.0  42473.00  51137.0
# Wednesday     12.0  37585.166667   8696.234889  25509.0  32927.00  36840.0
#
#                   75%      max
# day_of_week
# Friday       43537.00  49763.0
# Monday       37162.50  50559.0
# Saturday     46549.00  54242.0
# Sunday       48753.00  55359.0
# Thursday     49006.00  54621.0
# Tuesday      55024.00  56000.0
# Wednesday    41003.25  53570.0

# %%
#Attendance based off opponents#
sns.boxplot(x = 'opponent', y = 'attend', data = data)
plt.show()

# %%
#Same breakdown but scatter plot format#
plt.scatter(x = 'opponent', y = 'attend', data = data, )
plt.show()

# %%
#Describes data by opponent# 
data.groupby('opponent').attend.describe()
# Out:
#            count          mean           std      min       25%      50%  \
# opponent
# Angels       3.0  49777.333333   5931.256893  43494.0  47026.50  50559.0
# Astros       3.0  35383.333333   1804.385306  33306.0  34794.50  36283.0
# Braves       3.0  32245.000000  10192.264763  26345.0  26360.50  26376.0
# Brewers      4.0  35358.750000  11926.816127  25509.0  26457.00  32394.5
# Cardinals    7.0  40853.285714   2803.223187  35754.0  39775.00  40906.0
# Cubs         3.0  44206.666667   2127.087759  42495.0  43016.00  43537.0
# Giants       9.0  39296.333333   7463.633599  32799.0  33993.00  36878.0
# Marlins      3.0  40665.333333   1101.663439  39805.0  40044.50  40284.0
# Mets         4.0  49586.250000   4565.136681  44217.0  47808.75  49384.5
# Nationals    3.0  49267.333333   4738.481860  44807.0  46780.00  48753.0
# Padres       9.0  42092.222222   7431.611951  31601.0  38359.00  40619.0
# Phillies     3.0  41897.000000  10762.222029  32238.0  36096.50  39955.0
# ...

# %%
#Looks at giveaways and day of week in month#
data.groupby(['month','day_of_week','cap','shirt','bobblehead','fireworks']).attend.describe()
# Out:
#                                                   count          mean  \
# month day_of_week cap shirt bobblehead fireworks
# APR   Friday      NO  NO    NO         YES          2.0  38204.000000
#       Monday      NO  NO    NO         NO           1.0  26376.000000
#       Saturday    NO  NO    NO         NO           1.0  46549.000000
#                             YES        NO           1.0  54242.000000
#       Sunday      NO  NO    NO         NO           1.0  38359.000000
#                       YES   NO         NO           1.0  48753.000000
#       Thursday    NO  NO    NO         NO           1.0  28328.000000
#       Tuesday     NO  NO    NO         NO           2.0  50007.000000
#       Wednesday   NO  NO    NO         NO           2.0  28037.000000
# AUG   Friday      NO  NO    NO         YES          3.0  40321.333333
#       Monday      NO  NO    NO         NO           2.0  34768.500000
#       Saturday    NO  NO    NO         NO           2.0  43436.000000
# ...

# %% [markdown]
# # Results #
# Looking at the data presented above in our charts. We can see the best night to have a giveaway to boost attendance would be on a Monday in October. This is because Monday's on average are the lowest attended games during the season. Ideally, this game would be in October which is the lowest attended month for the Dodgers. However, this is also based off opponents that the Dodgers play as well. The lowest attended opponent is the Atlanta Braves. On average I would recommend doing a giveaway on a Monday in the month of October. Especially if the team plays a low attended opponent like the Atlanta Braves. In these examples I broke down the means of the data and looked further at the standard deviations as well as the mins and maxs. Through doing this I was able to see which opponents or giveaways created higher attedance during a low attendance time period. In my opinion the Dodgers should focuse on their 3 lowest attended months which are October, May, September pairing that with opponent like the Braves, Astros, or Brewers. These months and opponents are low attended times and teams, which in turn makes the decision process easier for giveaways. These giveaways as shown in the data above help improve attendance and allow for more fans to come to games. Pairing giveaways with typical low attendance games allow for an increase in attendance during tiime periods when fans may not come to games. Which is significant because it is creating attendance during low attedance time periods.
